# %%
# !pip install langchain-openai

# %%
import openai
import os

# %%
os.environ["OPENAI_API_KEY"] = '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'
#export OPENAI_API_KEY="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"
openai.api_key = os.getenv('OPENAI_API_KEY')
#openai.api_key

# %%
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAI

llm = OpenAI(openai_api_key=openai.api_key)
chat_model = ChatOpenAI(model="gpt-3.5-turbo-0125")

# %%
print(llm('Here is a fun fact about pluto:'))
# Out:
# C:\Users\817840\AppData\Roaming\Python\Python39\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\httpx\_transports\default.py in map_httpcore_exceptions()
#      68     try:
# ---> 69         yield
#      70     except Exception as exc:
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpx\_transports\default.py in handle_request(self, request)
#     232         with map_httpcore_exceptions():
# --> 233             resp = self._pool.handle_request(req)
#     234
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpcore\_sync\connection_pool.py in handle_request(self, request)
#     215             self._close_connections(closing)
# --> 216             raise exc from None
#     217
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpcore\_sync\connection_pool.py in handle_request(self, request)
#     195                     # Send the request on the assigned connection.
# --> 196                     response = connection.handle_request(
#     197                         pool_request.request
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpcore\_sync\connection.py in handle_request(self, request)
#      98             self._connect_failed = True
# ---> 99             raise exc
#     100
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpcore\_sync\connection.py in handle_request(self, request)
#      75                 if self._connection is None:
# ---> 76                     stream = self._connect(request)
#      77
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpcore\_sync\connection.py in _connect(self, request)
#     153                     with Trace("start_tls", logger, request, kwargs) as trace:
# --> 154                         stream = stream.start_tls(**kwargs)
#     155                         trace.return_value = stream
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpcore\_backends\sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#     167                 self.close()
# --> 168                 raise exc
#     169         return SyncStream(sock)
#
# C:\ProgramData\Anaconda3\lib\contextlib.py in __exit__(self, typ, value, traceback)
#     136             try:
# --> 137                 self.gen.throw(typ, value, traceback)
#     138             except StopIteration as exc:
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpcore\_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     917         try:
# --> 918             response = self._client.send(
#     919                 request,
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpx\_client.py in send(self, request, stream, auth, follow_redirects)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpx\_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpx\_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpx\_client.py in _send_single_request(self, request)
#    1014         with request_context(request=request):
# -> 1015             response = transport.handle_request(request)
#    1016
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpx\_transports\default.py in handle_request(self, request)
#     232         with map_httpcore_exceptions():
# --> 233             resp = self._pool.handle_request(req)
#     234
#
# C:\ProgramData\Anaconda3\lib\contextlib.py in __exit__(self, typ, value, traceback)
#     136             try:
# --> 137                 self.gen.throw(typ, value, traceback)
#     138             except StopIteration as exc:
#
# ~\AppData\Roaming\Python\Python39\site-packages\httpx\_transports\default.py in map_httpcore_exceptions()
#      85         message = str(exc)
# ---> 86         raise mapped_exc(message) from exc
#      87
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10168\908340944.py in <module>
# ----> 1 print(llm('Here is a fun fact about pluto:'))
#
# ~\AppData\Roaming\Python\Python39\site-packages\langchain_core\_api\deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     143                 warned = True
#     144                 emit_warning()
# --> 145             return wrapped(*args, **kwargs)
#     146
#     147         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# ~\AppData\Roaming\Python\Python39\site-packages\langchain_core\language_models\llms.py in __call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#     989             )
#     990         return (
# --> 991             self.generate(
#     992                 [prompt],
#     993                 stop=stop,
#
# ~\AppData\Roaming\Python\Python39\site-packages\langchain_core\language_models\llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, **kwargs)
#     739                 )
#     740             ]
# --> 741             output = self._generate_helper(
#     742                 prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     743             )
#
# ~\AppData\Roaming\Python\Python39\site-packages\langchain_core\language_models\llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     603             for run_manager in run_managers:
#     604                 run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 605             raise e
#     606         flattened_outputs = output.flatten()
#     607         for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# ~\AppData\Roaming\Python\Python39\site-packages\langchain_core\language_models\llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     590         try:
#     591             output = (
# --> 592                 self._generate(
#     593                     prompts,
#     594                     stop=stop,
#
# ~\AppData\Roaming\Python\Python39\site-packages\langchain_openai\llms\base.py in _generate(self, prompts, stop, run_manager, **kwargs)
#     354                 )
#     355             else:
# --> 356                 response = self.client.create(prompt=_prompts, **params)
#     357                 if not isinstance(response, dict):
#     358                     # V1 client returns the response in an PyDantic object instead of
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_utils\_utils.py in wrapper(*args, **kwargs)
#     273                         msg = f"Missing required argument: {quote(missing[0])}"
#     274                 raise TypeError(msg)
# --> 275             return func(*args, **kwargs)
#     276
#     277         return wrapper  # type: ignore
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\resources\completions.py in create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     504         timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     505     ) -> Completion | Stream[Completion]:
# --> 506         return self._post(
#     507             "/completions",
#     508             body=maybe_transform(
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1198             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1199         )
# -> 1200         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1201
#    1202     def patch(
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     887         stream_cls: type[_StreamT] | None = None,
#     888     ) -> ResponseT | _StreamT:
# --> 889         return self._request(
#     890             cast_to=cast_to,
#     891             options=options,
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     940
#     941             if retries > 0:
# --> 942                 return self._retry_request(
#     943                     options,
#     944                     cast_to,
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1011         time.sleep(timeout)
#    1012
# -> 1013         return self._request(
#    1014             options=options,
#    1015             cast_to=cast_to,
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     940
#     941             if retries > 0:
# --> 942                 return self._retry_request(
#     943                     options,
#     944                     cast_to,
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1011         time.sleep(timeout)
#    1012
# -> 1013         return self._request(
#    1014             options=options,
#    1015             cast_to=cast_to,
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     950
#     951             log.debug("Raising connection error")
# --> 952             raise APIConnectionError(request=request) from err
#     953
#     954         log.debug(
#
# APIConnectionError: Connection error.
